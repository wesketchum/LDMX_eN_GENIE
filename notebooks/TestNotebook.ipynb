// %%
#include "ROOT/RDataFrame.hxx"

// %%
%jsroot on

// %%
TFile my_file("/pnfs/dune/scratch/users/wketchum/eN_Ti_GENIE_v3_2_0/ldmx_eTi_4GeV_GEM21_11b_00/ldmx_eTi_4GeV_GEM21_11b_00_run98.gst.root", "READ");

// %%
my_file.ls()
// Out:
// TFile**		/pnfs/dune/scratch/users/wketchum/eN_Ti_GENIE_v3_2_0/ldmx_eTi_4GeV_GEM21_11b_00/ldmx_eTi_4GeV_GEM21_11b_00_run98.gst.root
//  TFile*		/pnfs/dune/scratch/users/wketchum/eN_Ti_GENIE_v3_2_0/ldmx_eTi_4GeV_GEM21_11b_00/ldmx_eTi_4GeV_GEM21_11b_00_run98.gst.root
//   KEY: TTree	gst;2	GENIE Summary Event Tree
//   KEY: TTree	gst;1	GENIE Summary Event Tree

// %%
TTree* gst_tree = (TTree*)my_file.Get("gst");

// %%
gst_tree->Print()
// Out:
// ******************************************************************************
// *Tree    :gst       : GENIE Summary Event Tree                               *
// *Entries :   100000 : Total =        79482777 bytes  File  Size =   47535726 *
// *        :          : Tree compression factor =   1.67                       *
// ******************************************************************************
// *Br    0 :iev       : iev/I                                                  *
// *Entries :   100000 : Total  Size=     401098 bytes  File Size  =     140221 *
// *Baskets :        9 : Basket Size=     256000 bytes  Compression=   2.86     *
// *............................................................................*
// *Br    1 :neu       : neu/I                                                  *
// *Entries :   100000 : Total  Size=     401098 bytes  File Size  =       2886 *
// *Baskets :        9 : Basket Size=     256000 bytes  Compression= 138.82     *
// ...

// %%
ROOT::RDataFrame df_gst_all(*gst_tree);

// %%
auto df = df_gst_all.Define("ptl","sqrt(pxl*pxl+pyl*pyl)");

// %%
df = df.Define("thetazl","atan2(ptl,pzl)");

// %%
auto hist_ptl = df.Histo1D("ptl");

// %%
TCanvas c;

// %%
hist_ptl->Draw();
c.Draw();
// Out:
// <div id="root_plot_1651671370222"
//      style="width: 696px; height: 472px">
// </div>
// <script>
//
// function display_root_plot_1651671370222(Core) {
// ...
